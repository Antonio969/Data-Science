# %% [markdown]
# # >>>> Correlacion <<<<

# %% [markdown]
# #### Magnitud y direccion de una relacion lineal entre dos variables

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./Datos/personas.csv')
data
# Out:
#          altura        peso       ingreso  horas_trabajadas  ausencias
# 0    134.433878   70.617864   9973.577534         40.905476          4
# 1    167.158746  109.268295   8961.047249         41.576483          4
# 2    141.480812   81.034644   7437.977263         41.369239          5
# 3    123.227119   57.884172  12064.915290         41.537211          3
# 4    143.554951   93.581093   9296.396167         40.441203          4
# ..          ...         ...           ...               ...        ...
# 995  169.059462  109.612155   9998.522402         41.110352          4
# 996  151.873081   91.697127   6867.097603         40.617061          5
# 997  131.156800   78.301155   9757.539280         40.798085          4
# 998  156.454396   94.163603  11044.031510         41.443604          3
# 999  149.558353   87.134622  13222.253800         41.402637          2
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### Relacion entre altura y peso

# %%
plt.scatter(data['altura'],data['peso'])
plt.xlabel('Altura (cms)')
plt.ylabel('Peso (kgs)')
# Out:
# Text(0, 0.5, 'Peso (kgs)')

# %% [markdown]
# #### Relacion entre el Ingreso y las Horas trabajadas

# %%
plt.scatter(data['ingreso'],data['horas_trabajadas'])
plt.xlabel('Ingreso ($)')
plt.ylabel('Horas Trabajadas ()')
# La correlacion no nos dice nada con respecto a la causalidad
# Lo unico que nos indican es que tienen una relacion
# Out:
# Text(0, 0.5, 'Horas Trabajadas ()')

# %% [markdown]
# #### Relacion entre Ingreso y Ausencia

# %%
plt.scatter(data['ingreso'],data['ausencias'])
plt.xlabel('Ingreso ($)')
plt.ylabel('Ausencias')
# Out:
# Text(0, 0.5, 'Ausencias')

# %% [markdown]
# #### Relacion entre el Ingreso y el Peso de una persona

# %%
plt.scatter(data['ingreso'],data['peso'])
plt.xlabel('Ingreso ($)')
plt.ylabel('Peso (kgs)')
# Out:
# Text(0, 0.5, 'Peso (kgs)')

# %% [markdown]
# #### Matriz de correlacion

# %%
data.corr() # -1 (existe una relacion fuerte con pendiente negativa) 0 1 (existe una relacion fuerte con pendiente positiva)
# Out:
#                     altura      peso   ingreso  horas_trabajadas  ausencias
# altura            1.000000  0.930608 -0.025283          0.008547   0.025587
# peso              0.930608  1.000000 -0.029852         -0.002483   0.027450
# ingreso          -0.025283 -0.029852  1.000000          0.625514  -0.973104
# horas_trabajadas  0.008547 -0.002483  0.625514          1.000000  -0.603870
# ausencias         0.025587  0.027450 -0.973104         -0.603870   1.000000

# %%
matriz = data.corr()
plt.matshow(matriz, cmap='bwr',vmin=-1,vmax=1)
plt.xticks(range(5),data.columns, rotation= 45)
plt.yticks(range(5),data.columns)
for i in range(len(matriz.columns)):
    for j in range(len(matriz.columns)):
        plt.text(i,j, round(matriz.iloc[i,j], 2), ha='center', va='center')



plt.colorbar()
